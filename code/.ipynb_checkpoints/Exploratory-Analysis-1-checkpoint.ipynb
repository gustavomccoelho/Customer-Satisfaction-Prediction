# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %%
# Loading train and test data

train1 = pd.read_csv("../Dataset/train.csv") 
test1 = pd.read_csv("../Dataset/test.csv")

# %%
# Checking number of rows and columns

print(train1.shape)
print(test1.shape)
# Out:
# (76020, 371)
# (75818, 370)

# %%
# Analysing some basic Statistics

train1.describe()
# Out:
#                   ID           var3         var15  imp_ent_var16_ult1  \
# count   76020.000000   76020.000000  76020.000000        76020.000000
# mean    75964.050723   -1523.199277     33.212865           86.208265
# std     43781.947379   39033.462364     12.956486         1614.757313
# min         1.000000 -999999.000000      5.000000            0.000000
# 25%     38104.750000       2.000000     23.000000            0.000000
# 50%     76043.000000       2.000000     28.000000            0.000000
# 75%    113748.750000       2.000000     40.000000            0.000000
# max    151838.000000     238.000000    105.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             76020.000000             76020.000000
# mean                 72.363067               119.529632
# std                 339.315831               546.266294
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               12888.030000             21024.810000
#
#        imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# count             76020.000000             76020.000000
# mean                  3.559130                 6.472698
# std                  93.155749               153.737066
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                8237.820000             11073.570000
#
#        imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  ...  \
# count             76020.000000             76020.000000  ...
# mean                  0.412946                 0.567352  ...
# std                  30.604864                36.513513  ...
# min                   0.000000                 0.000000  ...
# 25%                   0.000000                 0.000000  ...
# 50%                   0.000000                 0.000000  ...
# 75%                   0.000000                 0.000000  ...
# max                6600.000000              6600.000000  ...
#
#        saldo_medio_var33_hace2  saldo_medio_var33_hace3  \
# count             76020.000000             76020.000000
# mean                  7.935824                 1.365146
# std                 455.887218               113.959637
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               50003.880000             20385.720000
#
#        saldo_medio_var33_ult1  saldo_medio_var33_ult3  \
# count            76020.000000            76020.000000
# mean                12.215580                8.784074
# std                783.207399              538.439211
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  0.000000                0.000000
# max             138831.630000            91778.730000
#
#        saldo_medio_var44_hace2  saldo_medio_var44_hace3  \
# count             76020.000000             76020.000000
# mean                 31.505324                 1.858575
# std                2013.125393               147.786584
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max              438329.220000             24650.010000
#
#        saldo_medio_var44_ult1  saldo_medio_var44_ult3         var38  \
# count            76020.000000            76020.000000  7.602000e+04
# mean                76.026165               56.614351  1.172358e+05
# std               4040.337842             2852.579397  1.826646e+05
# min                  0.000000                0.000000  5.163750e+03
# 25%                  0.000000                0.000000  6.787061e+04
# 50%                  0.000000                0.000000  1.064092e+05
# 75%                  0.000000                0.000000  1.187563e+05
# max             681462.900000           397884.300000  2.203474e+07
#
#              TARGET
# count  76020.000000
# mean       0.039569
# std        0.194945
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 371 columns]

# %%
# Checking NAN values

print(train1.isnull().values.sum())
print(test1.isnull().values.sum())
# Out:
# 0
# 0

# %%
#Checking data balance according to target variable

Positive = train1[train1["TARGET"] == 1]
print(Positive.shape)
Negative = train1[train1["TARGET"] == 0]
print(Negative.shape)
# Out:
# (3008, 371)
# (73012, 371)

# %%
# Balancing data

train2 = train1[train1["TARGET"] == 0].sample(3008).append(train1[train1["TARGET"] == 1])
Positive = train2[train2["TARGET"] == 1]
print(Positive.shape)
Negative = train2[train2["TARGET"] == 0]
print(Negative.shape)
# Out:
# (3008, 371)
# (3008, 371)

# %%
# Removing variables with high correlation between each other, i.e they represent the same information 

train_corr = train2.corr(method = 'pearson')
train_corr = np.array(train_corr.fillna(0))
aux = []

for i in range(len(train2.columns)-1):
    for j in range(i+1, len(train_corr)-1):
            if abs(train_corr[i][j]) > 0.95 and j not in aux:
                aux.append(j)
print("Number of removed columns: " + str(len(aux)))
train3 = train2.drop(train2.columns[aux], axis = 1)
test3 = test1.drop(train2.columns[aux], axis = 1)
train3.describe()
# Out:
# Number of removed columns: 117
#                   ID           var3        var15  imp_ent_var16_ult1  \
# count    6016.000000    6016.000000  6016.000000         6016.000000
# mean    76024.004156   -1161.097241    36.315326           89.942907
# std     44245.421445   34094.085054    12.835223         1476.421694
# min        31.000000 -999999.000000     6.000000            0.000000
# 25%     37429.000000       2.000000    25.000000            0.000000
# 50%     76383.500000       2.000000    34.000000            0.000000
# 75%    114945.000000       2.000000    44.000000            0.000000
# max    151811.000000     204.000000   102.000000        76500.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count              6016.000000              6016.000000
# mean                 77.442542               115.473979
# std                 390.774389               524.911264
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max               12888.030000             13183.230000
#
#        imp_op_var40_comer_ult1  imp_op_var40_efect_ult1  \
# count              6016.000000              6016.000000
# mean                  3.569965                 1.655585
# std                  80.581819                44.662790
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                3639.870000              1800.000000
#
#        imp_op_var40_efect_ult3  imp_op_var40_ult1  ...  \
# count              6016.000000        6016.000000  ...
# mean                  2.099402           3.493469  ...
# std                  58.268711          75.123956  ...
# min                   0.000000           0.000000  ...
# 25%                   0.000000           0.000000  ...
# 50%                   0.000000           0.000000  ...
# 75%                   0.000000           0.000000  ...
# max                3000.000000        2986.980000  ...
#
#        saldo_medio_var17_hace2  saldo_medio_var17_hace3  \
# count                   6016.0                   6016.0
# mean                       0.0                      0.0
# std                        0.0                      0.0
# min                        0.0                      0.0
# 25%                        0.0                      0.0
# 50%                        0.0                      0.0
# 75%                        0.0                      0.0
# max                        0.0                      0.0
#
#        saldo_medio_var29_hace2  saldo_medio_var29_hace3  \
# count                   6016.0                   6016.0
# mean                       0.0                      0.0
# std                        0.0                      0.0
# min                        0.0                      0.0
# 25%                        0.0                      0.0
# 50%                        0.0                      0.0
# 75%                        0.0                      0.0
# max                        0.0                      0.0
#
#        saldo_medio_var29_ult1  saldo_medio_var29_ult3  \
# count                  6016.0                  6016.0
# mean                      0.0                     0.0
# std                       0.0                     0.0
# min                       0.0                     0.0
# 25%                       0.0                     0.0
# 50%                       0.0                     0.0
# 75%                       0.0                     0.0
# max                       0.0                     0.0
#
#        saldo_medio_var44_hace2  saldo_medio_var44_hace3         var38  \
# count              6016.000000                   6016.0  6.016000e+03
# mean                  0.025342                      0.0  1.077173e+05
# std                   1.965631                      0.0  1.006120e+05
# min                   0.000000                      0.0  8.290860e+03
# 25%                   0.000000                      0.0  6.304610e+04
# 50%                   0.000000                      0.0  9.741282e+04
# 75%                   0.000000                      0.0  1.173110e+05
# max                 152.460000                      0.0  3.988595e+06
#
#             TARGET
# count  6016.000000
# mean      0.500000
# std       0.500042
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 254 columns]

# %%
# Removing columns with correlation lower than 0.18 to the target variable

train_corr = train3.corr(method = 'pearson')["TARGET"]
train_corr = train_corr.fillna(0)
train4 = train3
test4 = test3

i = len(train_corr) - 2

while i >= 0:
    if abs(train_corr[i]) < 0.18:
        train4 = train4.drop(train_corr.index[i],1)
        test4 = test4.drop(train_corr.index[i],1)
    i -= 1
    
train4.describe()
# Out:
#              var15     ind_var5    ind_var30     num_var4    num_var30  \
# count  6016.000000  6016.000000  6016.000000  6016.000000  6016.000000
# mean     36.315326     0.512301     0.576961     0.896941     1.834608
# std      12.835223     0.499890     0.494082     0.966445     1.670557
# min       6.000000     0.000000     0.000000     0.000000     0.000000
# 25%      25.000000     0.000000     0.000000     0.000000     0.000000
# 50%      34.000000     1.000000     1.000000     1.000000     3.000000
# 75%      44.000000     1.000000     1.000000     1.000000     3.000000
# max     102.000000     1.000000     1.000000     5.000000     9.000000
#
#          num_var42        var36  num_meses_var5_ult3       TARGET
# count  6016.000000  6016.000000          6016.000000  6016.000000
# mean      1.729887    52.232547             1.533910     0.500000
# std       1.573474    48.453698             1.387456     0.500042
# min       0.000000     0.000000             0.000000     0.000000
# 25%       0.000000     2.000000             0.000000     0.000000
# 50%       3.000000    99.000000             2.000000     0.500000
# 75%       3.000000    99.000000             3.000000     1.000000
# max       9.000000    99.000000             3.000000     1.000000

# %%
# Applying PCA to the low correlation variables

trainPCA = train3
testPCA = test3
i = len(train_corr) - 2

while i >= 0:
    if (abs(train_corr[i]) < 0.03) or (abs(train_corr[i]) > 0.18):
        trainPCA = trainPCA.drop(train_corr.index[i],1)
        testPCA = testPCA.drop(train_corr.index[i],1)
    i -= 1

trainPCA = trainPCA.drop("TARGET",1)

# Applying PCA

pca = PCA(n_components=3)
trainPCA = pd.DataFrame(pca.fit_transform(trainPCA))
testPCA = pd.DataFrame(pca.fit_transform(testPCA))

train4["PCA0"] = trainPCA[0].values
train4["PCA1"] = trainPCA[1].values
train4["PCA2"] = trainPCA[2].values

test4["PCA0"] = testPCA[0].values
test4["PCA1"] = testPCA[1].values
test4["PCA2"] = testPCA[2].values

print("The PCA explained variance ratio is: " + str(sum(pca.explained_variance_ratio_)*1))
# Out:
# The PCA explained variance ratio is: 0.9595383615800795

# %%
# Making boxplot

train4.boxplot(grid = False, figsize = (18,5))

# %%
# Removing outliers

train4 = train4[(np.abs(stats.zscore(train4)) < 3).all(axis=1)]

# %%
# Making boxplot

train4.boxplot(grid = False, figsize = (18,5))

# %%
# Creating a variable to count the number of zeros for each ID

train4["Zeros"] = train4.apply(lambda x: sum(x == 0), 1)
test4["Zeros"] = test4.apply(lambda x: sum(x == 0), 1)
    
# Normalizing Data

scaler = MinMaxScaler(feature_range = (0, 1))
train4 = pd.DataFrame(scaler.fit_transform(train4), columns=train4.columns)

# %%
# Making boxplot

train4.boxplot(grid = False, figsize = (18,5))

# %%
# Saving data

train4.to_csv("../Dataset/train_1.csv")
test4.to_csv("../Dataset/test_1.csv")
